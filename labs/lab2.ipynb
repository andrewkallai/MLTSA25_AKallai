# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewkallai/MLTSA25_AKallai/blob/main/labs/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
np.random.seed(302)
mydist = np.random.randn(100)
mydist[0]

# %%
mydist = np.random.randn(100)

# %%
mydist
# Out:
# array([-0.23871663, -0.06800857, -0.19056061, -0.25006472,  1.44219666,
#         0.42952445, -0.85101312,  1.46920096, -0.62405527,  1.38119534,
#        -0.40047907, -0.43366484, -1.55735074, -0.03961691, -0.7411376 ,
#         0.2549131 , -0.96327964, -0.00820785, -0.87674249,  0.29652207,
#        -1.13212092,  1.38394897, -0.14671339, -2.09545319, -0.42364259,
#         0.65891925,  0.14034327, -0.52408239, -2.6083828 ,  1.68193261,
#         1.81305141,  0.96662112, -0.53131627,  1.14937364, -1.40054748,
#        -0.30335258,  0.79346164,  0.84860034, -0.13058568, -0.00975299,
#        -1.66657107, -1.0784032 , -0.7476213 , -1.29463675,  0.77683191,
#        -0.62563985,  0.01196394, -0.93516658,  0.55654261,  1.37653257,
#        -0.55167351,  1.29683023, -1.31897436,  0.34042138, -1.44417588,
#         1.18285687,  2.1196799 ,  1.00267705, -0.06652846, -0.48643712,
#        -0.16812399, -0.64458966,  0.50916523, -1.89495089, -0.69095342,
# ...

# %%
plt.hist(mydist)
plt.xlabel("something")
plt.ylabel("counts")
# Out:
# Text(0, 0.5, 'counts')

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/fedhere/MLTSA_FBianco/refs/heads/main/data/grb050525A.csv"
grbAG = pd.read_csv(url)
grbAG
# Out:
#     filter     time    mag  magerr  upperlimit
# 0        V       66  13.21    0.24           0
# 1        V       67  12.90    0.23           0
# 2        V       68  12.86    0.23           0
# 3        V       69  13.01    0.23           0
# 4        V       70  12.97    0.23           0
# ..     ...      ...    ...     ...         ...
# 114     W1    63738    NaN   21.20           1
# 115     M2    74798    NaN   21.59           1
# 116      U   128928    NaN   20.05           1
# 117      V   971360    NaN   22.09           1
# 118      V  1171176    NaN   21.16           1
#
# [119 rows x 5 columns]

# %%
grbAG.columns
# Out:
# Index(['filter', 'time', 'mag', 'magerr', 'upperlimit'], dtype='object')

# %%
grbAG[['time', 'mag', 'magerr', 'upperlimit']].corr()
# Out:
#                 time       mag    magerr  upperlimit
# time        1.000000  0.846971  0.517663    0.506833
# mag         0.846971  1.000000  0.602576         NaN
# magerr      0.517663  0.602576  1.000000    0.999288
# upperlimit  0.506833       NaN  0.999288    1.000000

# %%
grbAG.plot(x="time", y="mag", kind='scatter')
# Out:
# <Axes: xlabel='time', ylabel='mag'>

# %%
grbAG['logtime'] = np.log10(grbAG.loc[:, "time"])

# %%
ax = grbAG.plot("logtime", "mag", kind="scatter", yerr='magerr')
ax.set_ylim(24, 11.7)
# Out:
# (24.0, 11.7)

# %%
np.c_?
x = grbAG["logtime"].values
np.c_[np.ones_like(x), x]
X
# Out:
# array([[1.81954394],
#        [1.8260748 ],
#        [1.83250891],
#        [1.83884909],
#        [1.84509804],
#        [1.85125835],
#        [1.8573325 ],
#        [1.86332286],
#        [1.8920946 ],
#        [1.91907809],
#        [1.94448267],
#        [1.96848295],
#        [1.99122608],
#        [2.01283722],
#        [2.03342376],
#        [2.05307844],
#        [2.07188201],
#        [2.08990511],
#        [2.10720997],
#        [2.12385164],
#        [2.13987909],
#        [2.15533604],
#        [2.17026172],
#        [2.18469143],
#        [2.19865709],
#        [2.2121876 ],
#        [2.22530928],
#        [2.2380461 ],
#        [2.27184161],
#        [2.30535137],
#        [2.33243846],
#        [2.35983548],
#        [2.38916608],
#        [2.41161971],
#        [2.4345689 ],
#        [2.45636603],
#        [2.47567119],
#        [2.49554434],
#        [2.5171959 ],
#        [2.53402611],
#        [2.55145   ],
#        [2.56820172],
#        [2.59879051],
# ...

# %%
X = np.atleast_2d(x).T
X
# Out:
# array([[1.81954394],
#        [1.8260748 ],
#        [1.83250891],
#        [1.83884909],
#        [1.84509804],
#        [1.85125835],
#        [1.8573325 ],
#        [1.86332286],
#        [1.8920946 ],
#        [1.91907809],
#        [1.94448267],
#        [1.96848295],
#        [1.99122608],
#        [2.01283722],
#        [2.03342376],
#        [2.05307844],
#        [2.07188201],
#        [2.08990511],
#        [2.10720997],
#        [2.12385164],
#        [2.13987909],
#        [2.15533604],
#        [2.17026172],
#        [2.18469143],
#        [2.19865709],
#        [2.2121876 ],
#        [2.22530928],
#        [2.2380461 ],
#        [2.27184161],
#        [2.30535137],
#        [2.33243846],
#        [2.35983548],
#        [2.38916608],
#        [2.41161971],
#        [2.4345689 ],
#        [2.45636603],
#        [2.47567119],
#        [2.49554434],
#        [2.5171959 ],
#        [2.53402611],
#        [2.55145   ],
#        [2.56820172],
#        [2.59879051],
# ...

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
x=grbAG["logtime"]
y=grbAG["mag"]
lr.fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-6e3abc8fe400> in <cell line: 0>()
#       3 x=grbAG["logtime"]
#       4 y=grbAG["mag"]
# ----> 5 lr.fit(x, y)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     599         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     600
# --> 601         X, y = validate_data(
#     602             self,
#     603             X,
#
# ...
