# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewkallai/MLTSA25_AKallai/blob/main/labs/lab_2_27_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.randn?

# %%
N = 100
np.random.seed(302)
y = np.random.randn(N)
plt.hist(y)
# Out:
# (array([ 4.,  7.,  4., 18., 17., 23., 14.,  9.,  2.,  2.]),
#  array([-2.67005842, -2.14052639, -1.61099437, -1.08146234, -0.55193032,
#         -0.02239829,  0.50713374,  1.03666576,  1.56619779,  2.09572982,
#          2.62526184]),
#  <BarContainer object of 10 artists>)

# %%
t = np.linspace(0,N, N)
t
# Out:
# array([  0.        ,   1.01010101,   2.02020202,   3.03030303,
#          4.04040404,   5.05050505,   6.06060606,   7.07070707,
#          8.08080808,   9.09090909,  10.1010101 ,  11.11111111,
#         12.12121212,  13.13131313,  14.14141414,  15.15151515,
#         16.16161616,  17.17171717,  18.18181818,  19.19191919,
#         20.2020202 ,  21.21212121,  22.22222222,  23.23232323,
#         24.24242424,  25.25252525,  26.26262626,  27.27272727,
#         28.28282828,  29.29292929,  30.3030303 ,  31.31313131,
#         32.32323232,  33.33333333,  34.34343434,  35.35353535,
#         36.36363636,  37.37373737,  38.38383838,  39.39393939,
#         40.4040404 ,  41.41414141,  42.42424242,  43.43434343,
#         44.44444444,  45.45454545,  46.46464646,  47.47474747,
#         48.48484848,  49.49494949,  50.50505051,  51.51515152,
#         52.52525253,  53.53535354,  54.54545455,  55.55555556,
#         56.56565657,  57.57575758,  58.58585859,  59.5959596 ,
# ...

# %%
plt.plot(t,y)
plt.xlabel("time")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
plt.hist(y[:50], alpha=0.4)
plt.hist(y[:50], alpha=0.6)
# Out:
# (array([ 2.,  4.,  1.,  9., 10.,  9., 10.,  2.,  2.,  1.]),
#  array([-2.67005842, -2.15973311, -1.64940779, -1.13908248, -0.62875717,
#         -0.11843185,  0.39189346,  0.90221877,  1.41254409,  1.9228694 ,
#          2.43319471]),
#  <BarContainer object of 10 artists>)
