# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewkallai/MLTSA25_AKallai/blob/main/labs/lab_3_6_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
from sklearn.gaussian_process  import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel, ExpSineSquared, WhiteKernel

# %%
np.random.seed(302)
t= [1., 3., 5., 6., 7., 8.]
t_ = np.atleast_2d(t)

# %%
def f(x):
  np.random.seed(302)
  x = x.ravel()
  return np.random.rand(len(x))

# %%
f(t_)
# Out:
# array([0.63628121, 0.82504234, 0.34164473, 0.73963926, 0.46915689,
#        0.54279063])

# %%
plt.plot(np.array(t).ravel(), f(t_))
